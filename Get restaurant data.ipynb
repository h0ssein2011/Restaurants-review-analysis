# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from collections import OrderedDict
import time

# %%
# Set headers
headers = requests.utils.default_headers()
headers.update({ 'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'})



url = "https://snappfood.ir/restaurant/city/Tehran"
req = requests.get(url)
soup = BeautifulSoup(req.content, 'lxml')
# print(soup.prettify())

base_link='https://snappfood.ir'
links=[]
restaurant_links=[]

for sp in soup.find_all('div'):
    sp=sp.find('a')
    try:
        hrefs=sp.attrs['href']
       
        links.append(base_link+hrefs)
        
#         
        
#         
#              restaurant_links.append(base_link+hrefs)
            
        
    except:
        pass

links=list(set(links))
print(len(links))
links=[link for link in links if 'menu' in link]
print(len(links))

print(links)
# Out:
# 30
# 21
# ['https://snappfood.ir/restaurant/menu/32mzde/mobin', 'https://snappfood.ir/restaurant/menu/pvrqq1/tochal/shariati', 'https://snappfood.ir/restaurant/menu/0jr4n9/bibi/yousefabad', 'https://snappfood.ir/restaurant/menu/p61963/perperook?branch_name=sohrevardi', 'https://snappfood.ir/restaurant/menu/094nkq/saharbakery/marzdaran', 'https://snappfood.ir/restaurant/menu/0l8er9/saadatabadsupermarket', 'https://snappfood.ir/restaurant/menu/3dqwzw/SUPERMARKETT?branch_name=dezashib', 'https://snappfood.ir/restaurant/menu/pvrqq1/tochal?branch_name=shariati', 'https://snappfood.ir/restaurant/menu/p4rn4x/beheshtisupermarket', 'https://snappfood.ir/restaurant/menu/094nkq/saharbakery?branch_name=marzdaran', 'https://snappfood.ir/restaurant/menu/3272d5/eslami', 'https://snappfood.ir/restaurant/menu/0l8er9/202', 'https://snappfood.ir/restaurant/menu/09wwlq/nanmari', 'https://snappfood.ir/restaurant/menu/0r5251/saharbakery?branch_name=saadatabad', 'https://snappfood.ir/restaurant/menu/3dq827/202/zargandeh', 'https://snappfood.ir/restaurant/menu/p4rn4x/202', 'https://snappfood.ir/restaurant/menu/3dqwzw/202/dezashib', 'https://snappfood.ir/restaurant/menu/3dq827/zooket?branch_name=zargandeh', 'https://snappfood.ir/restaurant/menu/0jr4n9/bibi?branch_name=yousefabad', 'https://snappfood.ir/restaurant/menu/p61963/perperook/sohrevardi', 'https://snappfood.ir/restaurant/menu/0r5251/saharbakery/saadatabad']

# %%
#create a function to go trough each link and get desired data
# create a dict to store data
restaurant={}
restaurant['name']=[]
restaurant['address']=[]
restaurant['persian_name']=[]


#add name restaurants

    
for url in links:
    tic=time.time()
    
    req = requests.get(url)
    soup = BeautifulSoup(req.content, 'lxml')
    En_name=url[url.rfind('/')+1:]
    address=soup.find('h2',itemprop="address",id="vendor-address").get_text().replace('آدرس','').strip()
    persian_name=soup.find('h1',itemprop="name",id="vendor-title").get_text().strip()
    
    
#     address=address[address.rfind('>'):]
    restaurant['name'].append(En_name)
    restaurant['address'].append(address)
    restaurant['persian_name'].append(persian_name)
    print((time.time()-tic),'second')
    

    
restaurant
# Out:
# 2.537217855453491 second
# 2.3766374588012695 second
# 2.4585354328155518 second
# 2.441476821899414 second
# 2.377610206604004 second
# 2.3510069847106934 second
# 6.7482805252075195 second
# 2.3321692943573 second
# 2.4673969745635986 second
# 2.654921531677246 second
# 2.4115278720855713 second
# 2.303870439529419 second
# 2.463407278060913 second
# 2.545788049697876 second
# 5.212430000305176 second
# 3.215937376022339 second
# 4.570794343948364 second
# 6.440099716186523 second
# 2.286881685256958 second
# 2.381659746170044 second
# 2.3569834232330322 second
# {'name': ['mobin',
#   'shariati',
#   'yousefabad',
#   'perperook?branch_name=sohrevardi',
#   'marzdaran',
#   'saadatabadsupermarket',
#   'SUPERMARKETT?branch_name=dezashib',
#   'tochal?branch_name=shariati',
#   'beheshtisupermarket',
#   'saharbakery?branch_name=marzdaran',
#   'eslami',
#   '202',
#   'nanmari',
#   'saharbakery?branch_name=saadatabad',
#   'zargandeh',
#   '202',
#   'dezashib',
#   'zooket?branch_name=zargandeh',
#   'bibi?branch_name=yousefabad',
#   'sohrevardi',
#   'saadatabad'],
#  'address': [': خیابان اسکندری جنوبی، پایین تر از آذربایجان، روبه روی فروشگاه اتکا، پلاک293، رستوران مبین',
#   ': خیابان شریعتی، دویست متر بالاتر از مترو قیطریه، نبش کوچه عاج، پلاک 1811، آبمیوه و بستنی توچال (شریعتی)',
#   ': یوسف آباد، میدان کلانتری، خیابان مدبر، نبش خیابان 30، شیرینی بی بی (یوسف آباد)',
#   ': سهروردی شمالی، خیابان آپادانا (خرمشهر)، نرسیده به قنبرزاده (مصلی)، پلاک 125، پیتزا پرپروک (آپادانا)',
#   ': مرزداران، 35 متری گلها، نبش میدان گلها، پلاک 8، نان سحر (مرزداران)',
#   ': سعادت اباد، سرو غربی ،خیابان صدف، نبش کوچه سپیدار ،سوپر مارکت سعادت آباد - بلوار پاکنژاد - درختی',
#   ': دزاشیب، سه راه عمار، ابتدای خیابان عمار، پلاک 1، زوکت دزاشیب - جماران (هایپر مارکت)',
#   ': خیابان شریعتی، دویست متر بالاتر از مترو قیطریه، نبش کوچه عاج، پلاک 1811، آبمیوه و بستنی توچال (شریعتی)',
#   ': خیابان ولیعصر، پایین تر از بهشتی، نرسیده به مطهری، پلاک 2029، سوپرمارکت بهشتی - مطهری - فاطمی',
#   ': مرزداران، 35 متری گلها، نبش میدان گلها، پلاک 8، نان سحر (مرزداران)',
#   ': بزرگراه نواب، پائین تر از میدان جمهوری، نبش آذربایجان، پلاک 524، چلو کبابی اسلامی',
#   ': سعادت اباد، سرو غربی ،خیابان صدف، نبش کوچه سپیدار ،سوپر مارکت سعادت آباد - بلوار پاکنژاد - درختی',
#   ': میدان پونک، خیابان میرزا بابایی، بلوار عدل، به سمت شمال، نرسیده به خیابان بهار، نان و شیرینی ماری',
#   ': سعادت آباد، بلوار دریا، بین مطهری و شفق، پلاک 102، نان سحر (سعادت آباد)',
#   ': ظفر، انتهای خیابان فرید افشار، دولتشاه شرقی، نبش جام، زوکت زرگنده (هایپر مارکت)',
#   ': خیابان ولیعصر، پایین تر از بهشتی، نرسیده به مطهری، پلاک 2029، سوپرمارکت بهشتی - مطهری - فاطمی',
#   ': دزاشیب، سه راه عمار، ابتدای خیابان عمار، پلاک 1، زوکت دزاشیب - جماران (هایپر مارکت)',
#   ': ظفر، انتهای خیابان فرید افشار، دولتشاه شرقی، نبش جام، زوکت زرگنده (هایپر مارکت)',
#   ': یوسف آباد، میدان کلانتری، خیابان مدبر، نبش خیابان 30، شیرینی بی بی (یوسف آباد)',
#   ': سهروردی شمالی، خیابان آپادانا (خرمشهر)، نرسیده به قنبرزاده (مصلی)، پلاک 125، پیتزا پرپروک (آپادانا)',
#   ': سعادت آباد، بلوار دریا، بین مطهری و شفق، پلاک 102، نان سحر (سعادت آباد)'],
#  'persian_name': ['رستوران مبین',
#   'آبمیوه و بستنی توچال (شریعتی)',
#   'شیرینی بی بی (یوسف آباد)',
#   'پیتزا پرپروک (آپادانا)',
#   'نان سحر (مرزداران)',
#   'سوپرمارکت باربد ( بلوار پاکنژاد - سعادت آباد - درختی)',
#   'سوپرمارکت تجریش - فرمانیه - جماران',
#   'آبمیوه و بستنی توچال (شریعتی)',
#   'سوپرمارکت بهشتی - مطهری - فاطمی',
#   'نان سحر (مرزداران)',
#   'چلو کبابی اسلامی',
#   'سوپرمارکت باربد ( بلوار پاکنژاد - سعادت آباد - درختی)',
#   'نان و شیرینی ماری',
#   'نان سحر (سعادت آباد)',
#   'سوپرمارکت سحر (زرگنده - میرداماد - قلهک)',
#   'سوپرمارکت بهشتی - مطهری - فاطمی',
#   'سوپرمارکت تجریش - فرمانیه - جماران',
#   'سوپرمارکت سحر (زرگنده - میرداماد - قلهک)',
#   'شیرینی بی بی (یوسف آباد)',
#   'پیتزا پرپروک (آپادانا)',
#   'نان سحر (سعادت آباد)']}

# %%
df_restaurants=pd.DataFrame(restaurant)
df_restaurants
# Out:
#                                   name  \
# 0                                mobin
# 1                             shariati
# 2                           yousefabad
# 3     perperook?branch_name=sohrevardi
# 4                            marzdaran
# 5                saadatabadsupermarket
# 6    SUPERMARKETT?branch_name=dezashib
# 7          tochal?branch_name=shariati
# 8                  beheshtisupermarket
# 9    saharbakery?branch_name=marzdaran
# 10                              eslami
# 11                                 202
# 12                             nanmari
# 13  saharbakery?branch_name=saadatabad
# 14                           zargandeh
# 15                                 202
# 16                            dezashib
# 17        zooket?branch_name=zargandeh
# 18         bibi?branch_name=yousefabad
# 19                          sohrevardi
# 20                          saadatabad
#
#                                               address  \
# 0   : خیابان اسکندری جنوبی، پایین تر از آذربایجان،...
# 1   : خیابان شریعتی، دویست متر بالاتر از مترو قیطر...
# 2   : یوسف آباد، میدان کلانتری، خیابان مدبر، نبش خ...
# 3   : سهروردی شمالی، خیابان آپادانا (خرمشهر)، نرسی...
# 4   : مرزداران، 35 متری گلها، نبش میدان گلها، پلاک...
# 5   : سعادت اباد، سرو غربی ،خیابان صدف، نبش کوچه س...
# 6   : دزاشیب، سه راه عمار، ابتدای خیابان عمار، پلا...
# 7   : خیابان شریعتی، دویست متر بالاتر از مترو قیطر...
# 8   : خیابان ولیعصر، پایین تر از بهشتی، نرسیده به ...
# 9   : مرزداران، 35 متری گلها، نبش میدان گلها، پلاک...
# 10  : بزرگراه نواب، پائین تر از میدان جمهوری، نبش ...
# 11  : سعادت اباد، سرو غربی ،خیابان صدف، نبش کوچه س...
# 12  : میدان پونک، خیابان میرزا بابایی، بلوار عدل، ...
# 13  : سعادت آباد، بلوار دریا، بین مطهری و شفق، پلا...
# 14  : ظفر، انتهای خیابان فرید افشار، دولتشاه شرقی،...
# 15  : خیابان ولیعصر، پایین تر از بهشتی، نرسیده به ...
# 16  : دزاشیب، سه راه عمار، ابتدای خیابان عمار، پلا...
# 17  : ظفر، انتهای خیابان فرید افشار، دولتشاه شرقی،...
# 18  : یوسف آباد، میدان کلانتری، خیابان مدبر، نبش خ...
# 19  : سهروردی شمالی، خیابان آپادانا (خرمشهر)، نرسی...
# 20  : سعادت آباد، بلوار دریا، بین مطهری و شفق، پلا...
#
#                                          persian_name
# 0                                        رستوران مبین
# 1                       آبمیوه و بستنی توچال (شریعتی)
# 2                            شیرینی بی بی (یوسف آباد)
# 3                              پیتزا پرپروک (آپادانا)
# 4                                  نان سحر (مرزداران)
# 5   سوپرمارکت باربد ( بلوار پاکنژاد - سعادت آباد -...
# 6                  سوپرمارکت تجریش - فرمانیه - جماران
# 7                       آبمیوه و بستنی توچال (شریعتی)
# 8                     سوپرمارکت بهشتی - مطهری - فاطمی
# 9                                  نان سحر (مرزداران)
# 10                                   چلو کبابی اسلامی
# 11  سوپرمارکت باربد ( بلوار پاکنژاد - سعادت آباد -...
# 12                                  نان و شیرینی ماری
# 13                               نان سحر (سعادت آباد)
# 14           سوپرمارکت سحر (زرگنده - میرداماد - قلهک)
# 15                    سوپرمارکت بهشتی - مطهری - فاطمی
# 16                 سوپرمارکت تجریش - فرمانیه - جماران
# 17           سوپرمارکت سحر (زرگنده - میرداماد - قلهک)
# 18                           شیرینی بی بی (یوسف آباد)
# 19                             پیتزا پرپروک (آپادانا)
# 20                               نان سحر (سعادت آباد)

# %%
df_restaurants.iloc[3,1]
# Out:
# ': سهروردی شمالی، خیابان آپادانا (خرمشهر)، نرسیده به قنبرزاده (مصلی)، پلاک 125، پیتزا پرپروک (آپادانا)'
