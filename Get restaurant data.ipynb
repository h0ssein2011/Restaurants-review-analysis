# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from collections import OrderedDict
import time

# %%
# Set headers
headers = requests.utils.default_headers()
headers.update({ 'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'})



url = "https://snappfood.ir/restaurant/city/Tehran"
req = requests.get(url)
soup = BeautifulSoup(req.content, 'lxml')
# print(soup.prettify())

base_link='https://snappfood.ir'
links=[]
restaurant_links=[]

for sp in soup.find_all('div'):
    sp=sp.find('a')
    try:
        hrefs=sp.attrs['href']
       
        links.append(base_link+hrefs)
        
#         
        
#         
#              restaurant_links.append(base_link+hrefs)
            
        
    except:
        pass

links=list(set(links))
print(len(links))
#remove redundent links whic are not a restaurnt url
links=[link for link in links if 'menu' in link]
print(len(links))

print(links)
# Out:
# 27
# 18
# ['https://snappfood.ir/restaurant/menu/31lr74/Test', 'https://snappfood.ir/restaurant/menu/0jre5r/mamanpaz?branch_name=fatemi', 'https://snappfood.ir/restaurant/menu/p61963/perperook?branch_name=sohrevardi', 'https://snappfood.ir/restaurant/menu/p4rndr/Test/jordan', 'https://snappfood.ir/restaurant/menu/p61963/perperook/sohrevardi', 'https://snappfood.ir/restaurant/menu/porrxv/mamanpaz?branch_name=jahankodak', 'https://snappfood.ir/restaurant/menu/po9q5v/targol', 'https://snappfood.ir/restaurant/menu/0jxzq3/sadretehranrestaurant', 'https://snappfood.ir/restaurant/menu/37x8ym/arghavan', 'https://snappfood.ir/restaurant/menu/32mzde/mobin', 'https://snappfood.ir/restaurant/menu/0y194g/tehrani', 'https://snappfood.ir/restaurant/menu/0jre5r/mamanpaz', 'https://snappfood.ir/restaurant/menu/porrxv/mamanpaz/jahankodak', 'https://snappfood.ir/restaurant/menu/p4rndr/mamanpaz?branch_name=jordan', 'https://snappfood.ir/restaurant/menu/0rj2r1/ghadircatering', 'https://snappfood.ir/restaurant/menu/0w9jlv/haida/vanak', 'https://snappfood.ir/restaurant/menu/31lr74/buffet', 'https://snappfood.ir/restaurant/menu/0w9jlv/haida?branch_name=vanak']

# %%
#create a function to go trough each link and get desired data
# create a dict to store data
restaurant={}
restaurant['name']=[]
restaurant['address']=[]
restaurant['persian_name']=[]


#add name restaurants

    
for url in links:
    tic=time.time()
    
    req = requests.get(url)
    soup = BeautifulSoup(req.content, 'lxml')
    En_name=url[url.rfind('/')+1:]
    address=soup.find('h2',itemprop="address",id="vendor-address").get_text().replace('آدرس','').strip()
    persian_name=soup.find('h1',itemprop="name",id="vendor-title").get_text().strip()
    
    
#     address=address[address.rfind('>'):]
    restaurant['name'].append(En_name)
    restaurant['address'].append(address)
    restaurant['persian_name'].append(persian_name)
    print((time.time()-tic),'second')
    

    
restaurant
# Out:
# 2.564301013946533 second
# 2.6511001586914062 second
# 2.7369089126586914 second
# 2.6233434677124023 second
# 2.3692898750305176 second
# 2.574298620223999 second
# 2.121392011642456 second
# 2.1914262771606445 second
# 2.589089870452881 second
# 2.6116316318511963 second
# 2.257878065109253 second
# 2.638737440109253 second
# 2.6678099632263184 second
# 2.9082822799682617 second
# 2.02819561958313 second
# 2.0842366218566895 second
# 2.836240530014038 second
# 2.774289131164551 second
# {'name': ['Test',
#   'mamanpaz?branch_name=fatemi',
#   'perperook?branch_name=sohrevardi',
#   'jordan',
#   'sohrevardi',
#   'mamanpaz?branch_name=jahankodak',
#   'targol',
#   'sadretehranrestaurant',
#   'arghavan',
#   'mobin',
#   'tehrani',
#   'mamanpaz',
#   'jahankodak',
#   'mamanpaz?branch_name=jordan',
#   'ghadircatering',
#   'vanak',
#   'buffet',
#   'haida?branch_name=vanak'],
#  'address': [': جردن، کوچه گلفام، پاساژ امیر، طبقه همکف، ,واحد 12، بوفه',
#   ': خیابان ولیعصر، ابتدای فاطمی، پلاک 15، واحد یک، مامان پز (فاطمی)',
#   ': سهروردی شمالی، خیابان آپادانا (خرمشهر)، نرسیده به قنبرزاده (مصلی)، پلاک 125، پیتزا پرپروک (آپادانا)',
#   ': خیابان جردن، کوچه گلفام، پاساژ امیر، طبقه همکف، مامان پز (جردن)',
#   ': سهروردی شمالی، خیابان آپادانا (خرمشهر)، نرسیده به قنبرزاده (مصلی)، پلاک 125، پیتزا پرپروک (آپادانا)',
#   ': آفریقا، پایین تر از جهان کودک، نبش بن بست زاگرس، مامان پز (جهان کودک)',
#   ': جردن، خیابان گلشهر، برج آی تک، غذای خانگی ترگل',
#   ': یوسف آباد، بین کوچه 11 و 13، پلاک 77، رستوران صدر تهران',
#   ': آیت الله کاشانی، روبه روی شهرداری منطقه 5، پلاک 396، کترینگ ارغوان',
#   ': خیابان اسکندری جنوبی، پایین تر از آذربایجان، روبه روی فروشگاه اتکا، پلاک293، رستوران مبین',
#   ': خیابان شهید بهشتی، خیابان احمد قصیر، کوچه ی مقدس، کترینگ طهرانی',
#   ': خیابان ولیعصر، ابتدای فاطمی، پلاک 15، واحد یک، مامان پز (فاطمی)',
#   ': آفریقا، پایین تر از جهان کودک، نبش بن بست زاگرس، مامان پز (جهان کودک)',
#   ': خیابان جردن، کوچه گلفام، پاساژ امیر، طبقه همکف، مامان پز (جردن)',
#   ': خیابان ظفر، خیابان گوی آبادی، خیابان راجیان، کوچه دلیری، پلاک 9، کترینگ غدیر',
#   ': ضلع جنوبی میدان ونک، پلاک 13، هایدا (ونک)',
#   ': جردن، کوچه گلفام، پاساژ امیر، طبقه همکف، ,واحد 12، بوفه',
#   ': ضلع جنوبی میدان ونک، پلاک 13، هایدا (ونک)'],
#  'persian_name': ['بوفه',
#   'مامان پز (فاطمی)',
#   'پیتزا پرپروک (آپادانا)',
#   'مامان پز (جردن)',
#   'پیتزا پرپروک (آپادانا)',
#   'مامان پز (جهان کودک)',
#   'غذای خانگی ترگل',
#   'رستوران صدر طهران (یوسف آباد)',
#   'کترینگ ارغوان',
#   'رستوران مبین',
#   'گروه غذایی طهرانی',
#   'مامان پز (فاطمی)',
#   'مامان پز (جهان کودک)',
#   'مامان پز (جردن)',
#   'کترینگ غدیر',
#   'هایدا (ونک)',
#   'بوفه',
#   'هایدا (ونک)']}

# %%
df_restaurants=pd.DataFrame(restaurant)
df_restaurants
# Out:
#                                 name  \
# 0                               Test
# 1        mamanpaz?branch_name=fatemi
# 2   perperook?branch_name=sohrevardi
# 3                             jordan
# 4                         sohrevardi
# 5    mamanpaz?branch_name=jahankodak
# 6                             targol
# 7              sadretehranrestaurant
# 8                           arghavan
# 9                              mobin
# 10                           tehrani
# 11                          mamanpaz
# 12                        jahankodak
# 13       mamanpaz?branch_name=jordan
# 14                    ghadircatering
# 15                             vanak
# 16                            buffet
# 17           haida?branch_name=vanak
#
#                                               address  \
# 0   : جردن، کوچه گلفام، پاساژ امیر، طبقه همکف، ,وا...
# 1   : خیابان ولیعصر، ابتدای فاطمی، پلاک 15، واحد ی...
# 2   : سهروردی شمالی، خیابان آپادانا (خرمشهر)، نرسی...
# 3   : خیابان جردن، کوچه گلفام، پاساژ امیر، طبقه هم...
# 4   : سهروردی شمالی، خیابان آپادانا (خرمشهر)، نرسی...
# 5   : آفریقا، پایین تر از جهان کودک، نبش بن بست زا...
# 6    : جردن، خیابان گلشهر، برج آی تک، غذای خانگی ترگل
# 7   : یوسف آباد، بین کوچه 11 و 13، پلاک 77، رستورا...
# 8   : آیت الله کاشانی، روبه روی شهرداری منطقه 5، پ...
# 9   : خیابان اسکندری جنوبی، پایین تر از آذربایجان،...
# 10  : خیابان شهید بهشتی، خیابان احمد قصیر، کوچه ی ...
# 11  : خیابان ولیعصر، ابتدای فاطمی، پلاک 15، واحد ی...
# 12  : آفریقا، پایین تر از جهان کودک، نبش بن بست زا...
# 13  : خیابان جردن، کوچه گلفام، پاساژ امیر، طبقه هم...
# 14  : خیابان ظفر، خیابان گوی آبادی، خیابان راجیان،...
# 15        : ضلع جنوبی میدان ونک، پلاک 13، هایدا (ونک)
# 16  : جردن، کوچه گلفام، پاساژ امیر، طبقه همکف، ,وا...
# 17        : ضلع جنوبی میدان ونک، پلاک 13، هایدا (ونک)
#
#                      persian_name
# 0                            بوفه
# 1                مامان پز (فاطمی)
# 2          پیتزا پرپروک (آپادانا)
# 3                 مامان پز (جردن)
# 4          پیتزا پرپروک (آپادانا)
# 5            مامان پز (جهان کودک)
# 6                 غذای خانگی ترگل
# 7   رستوران صدر طهران (یوسف آباد)
# 8                   کترینگ ارغوان
# 9                    رستوران مبین
# 10              گروه غذایی طهرانی
# 11               مامان پز (فاطمی)
# 12           مامان پز (جهان کودک)
# 13                مامان پز (جردن)
# 14                    کترینگ غدیر
# 15                    هایدا (ونک)
# 16                           بوفه
# 17                    هایدا (ونک)

# %%
# df_restaurants['main_st']=df_restaurants['address'].str(0,df_restaurants['address'].str.find('،'))
df_restaurants['main_st']=df_restaurants['address'].apply(lambda x:x[0:x.find('،')]).str.replace(':','')
df_restaurants
# Out:
#                                 name  \
# 0                               Test
# 1        mamanpaz?branch_name=fatemi
# 2   perperook?branch_name=sohrevardi
# 3                             jordan
# 4                         sohrevardi
# 5    mamanpaz?branch_name=jahankodak
# 6                             targol
# 7              sadretehranrestaurant
# 8                           arghavan
# 9                              mobin
# 10                           tehrani
# 11                          mamanpaz
# 12                        jahankodak
# 13       mamanpaz?branch_name=jordan
# 14                    ghadircatering
# 15                             vanak
# 16                            buffet
# 17           haida?branch_name=vanak
#
#                                               address  \
# 0   : جردن، کوچه گلفام، پاساژ امیر، طبقه همکف، ,وا...
# 1   : خیابان ولیعصر، ابتدای فاطمی، پلاک 15، واحد ی...
# 2   : سهروردی شمالی، خیابان آپادانا (خرمشهر)، نرسی...
# 3   : خیابان جردن، کوچه گلفام، پاساژ امیر، طبقه هم...
# 4   : سهروردی شمالی، خیابان آپادانا (خرمشهر)، نرسی...
# 5   : آفریقا، پایین تر از جهان کودک، نبش بن بست زا...
# 6    : جردن، خیابان گلشهر، برج آی تک، غذای خانگی ترگل
# 7   : یوسف آباد، بین کوچه 11 و 13، پلاک 77، رستورا...
# 8   : آیت الله کاشانی، روبه روی شهرداری منطقه 5، پ...
# 9   : خیابان اسکندری جنوبی، پایین تر از آذربایجان،...
# 10  : خیابان شهید بهشتی، خیابان احمد قصیر، کوچه ی ...
# 11  : خیابان ولیعصر، ابتدای فاطمی، پلاک 15، واحد ی...
# 12  : آفریقا، پایین تر از جهان کودک، نبش بن بست زا...
# 13  : خیابان جردن، کوچه گلفام، پاساژ امیر، طبقه هم...
# 14  : خیابان ظفر، خیابان گوی آبادی، خیابان راجیان،...
# 15        : ضلع جنوبی میدان ونک، پلاک 13، هایدا (ونک)
# 16  : جردن، کوچه گلفام، پاساژ امیر، طبقه همکف، ,وا...
# 17        : ضلع جنوبی میدان ونک، پلاک 13، هایدا (ونک)
#
#                      persian_name                main_st
# 0                            بوفه                   جردن
# 1                مامان پز (فاطمی)          خیابان ولیعصر
# 2          پیتزا پرپروک (آپادانا)          سهروردی شمالی
# 3                 مامان پز (جردن)            خیابان جردن
# 4          پیتزا پرپروک (آپادانا)          سهروردی شمالی
# 5            مامان پز (جهان کودک)                 آفریقا
# 6                 غذای خانگی ترگل                   جردن
# 7   رستوران صدر طهران (یوسف آباد)              یوسف آباد
# 8                   کترینگ ارغوان        آیت الله کاشانی
# 9                    رستوران مبین   خیابان اسکندری جنوبی
# 10              گروه غذایی طهرانی      خیابان شهید بهشتی
# 11               مامان پز (فاطمی)          خیابان ولیعصر
# 12           مامان پز (جهان کودک)                 آفریقا
# 13                مامان پز (جردن)            خیابان جردن
# 14                    کترینگ غدیر             خیابان ظفر
# 15                    هایدا (ونک)    ضلع جنوبی میدان ونک
# 16                           بوفه                   جردن
# 17                    هایدا (ونک)    ضلع جنوبی میدان ونک

# %%
df_restaurants['main_st'].value_counts()
# Out:
#  جردن                    3
#  خیابان جردن             2
#  خیابان ولیعصر           2
#  آفریقا                  2
#  ضلع جنوبی میدان ونک     2
#  سهروردی شمالی           2
#  خیابان اسکندری جنوبی    1
#  آیت الله کاشانی         1
#  خیابان ظفر              1
#  یوسف آباد               1
#  خیابان شهید بهشتی       1
# Name: main_st, dtype: int64

# %%
def resturant_data_collector(link):
    restaurant_data={}
    restaurant_data['location'] =[]
    restaurant_data['restaurant_name']=[]
    restaurant_data['food_name']=[]
    restaurant_data['food_price']=[]
    
    
    
    req = requests.get(link)
    soup = BeautifulSoup(req.content, 'lxml')
    restaurant_name = soup.find_all('')
    restaurant_data['restaurant_name'].append( soup.find('h1' ,id="vendor-title").get_text())
    restaurant_data['location'].append( soup.find('h2' ,id="vendor-address").get_text())
    restaurant_data['food_name'].append(soup.findAll('span',attrs={'style':'position: relative; right: 0px;'}))
    restaurant_data['food_price'].append( soup.findAll('span' ,attrs={'class':"kk-price"}))

    # spans = soup.findAll('span', attrs = {'class' : 'your-class-name'}) # or span by class name


    
    
    
#     restaurant_name=restaurant_name.append(link[link.rfind('/'):])
#     if tags.get() == 'span' and classes == 'my_product_title':
        
#         food_name=food_name.append(soup.find(tag,calss=classes).get_text())
#     if tag.get() == 'h4'and classes == 'kk-price':
#         food_price=food_price.append(soup.find(tag,calss=classes).get_text()))
        
        
        
#     req = requests.get(url)
# soup = BeautifulSoup(req.content, 'lxml')
# # print(soup.prettify())

# base_link='https://snappfood.ir'
# links=[]
# restaurant_links=[]

# for sp in soup.find_all('div'):
#     sp=sp.find('a')
#     try:
#         hrefs=sp.attrs['href']
       
#         links.append(base_link+hrefs)
    return restaurant_data

# %%
resturant_data_collector(links[0])
# Out:
# {'location': [' آدرس                        : جردن، کوچه گلفام، پاساژ امیر، طبقه همکف، ,واحد 12، بوفه'],
#  'restaurant_name': ['بوفه'],
#  'food_name': [[]],
#  'food_price': [[]]}
