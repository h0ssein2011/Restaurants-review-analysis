# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from collections import OrderedDict
import time

# %%
# Set headers
headers = requests.utils.default_headers()
headers.update({ 'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'})



url = "https://snappfood.ir/restaurant/city/Tehran"
req = requests.get(url)
soup = BeautifulSoup(req.content, 'lxml')
# print(soup.prettify())

base_link='https://snappfood.ir'
links=[]
restaurant_links=[]

for sp in soup.find_all('div'):
    sp=sp.find('a')
    try:
        hrefs=sp.attrs['href']
       
        links.append(base_link+hrefs)
        
#         
        
#         
#              restaurant_links.append(base_link+hrefs)
            
        
    except:
        pass

links=list(set(links))
print(len(links))
links=[link for link in links if 'menu' in link]
print(len(links))

print(links)
# Out:
# 27
# 18
# ['https://snappfood.ir/restaurant/menu/pzng4j/arshiasepehr/%D9%81%D8%A7%D8%B7%D9%85%DB%8C', 'https://snappfood.ir/restaurant/menu/0rj2r1/ghadircatering', 'https://snappfood.ir/restaurant/menu/p61963/perperook?branch_name=sohrevardi', 'https://snappfood.ir/restaurant/menu/37x8ym/arghavan', 'https://snappfood.ir/restaurant/menu/3dqqkd/mazzeh?branch_name=tavanir', 'https://snappfood.ir/restaurant/menu/3dqqkd/mazeh/tavanir', 'https://snappfood.ir/restaurant/menu/po994q/bowrani', 'https://snappfood.ir/restaurant/menu/3d5qew/hani?branch_name=andarzgoo', 'https://snappfood.ir/restaurant/menu/0jxzq3/sadretehranrestaurant', 'https://snappfood.ir/restaurant/menu/0q6r92/Test', 'https://snappfood.ir/restaurant/menu/pzng4j/arshia?branch_name=%D9%81%D8%A7%D8%B7%D9%85%DB%8C', 'https://snappfood.ir/restaurant/menu/32mzde/mobin', 'https://snappfood.ir/restaurant/menu/3d5qew/hani/andarzgoo', 'https://snappfood.ir/restaurant/menu/0wlr8p/burgerator/tehran', 'https://snappfood.ir/restaurant/menu/0q6r92/kibo', 'https://snappfood.ir/restaurant/menu/0wlr8p/burgerator?branch_name=tehran', 'https://snappfood.ir/restaurant/menu/p61963/perperook/sohrevardi', 'https://snappfood.ir/restaurant/menu/0y194g/tehrani']

# %%
#create a function to go trough each link and get desired data
# create a dict to store data
restaurant={}
restaurant['name']=[]
restaurant['address']=[]
restaurant['persian_name']=[]


#add name restaurants

    
for url in links:
    tic=time.time()
    
    req = requests.get(url)
    soup = BeautifulSoup(req.content, 'lxml')
    En_name=url[url.rfind('/')+1:]
    address=soup.find('h2',itemprop="address",id="vendor-address").get_text().replace('آدرس','').strip()
    persian_name=soup.find('h1',itemprop="name",id="vendor-title").get_text().strip()
    
    
#     address=address[address.rfind('>'):]
    restaurant['name'].append(En_name)
    restaurant['address'].append(address)
    restaurant['persian_name'].append(persian_name)
    print((time.time()-tic),'second')
    

    
restaurant
# Out:
# 1.9393362998962402 second
# 1.7772471904754639 second
# 3.258286237716675 second
# 2.2938919067382812 second
# 3.1724822521209717 second
# 1.8849973678588867 second
# 1.7871813774108887 second
# 1.8690268993377686 second
# 1.8291549682617188 second
# 1.7941973209381104 second
# 2.6302647590637207 second
# 1.974120855331421 second
# 2.0106236934661865 second
# 1.808197021484375 second
# 1.9767093658447266 second
# 1.9168710708618164 second
# 2.300816059112549 second
# 1.7713534832000732 second
# {'name': ['%D9%81%D8%A7%D8%B7%D9%85%DB%8C',
#   'ghadircatering',
#   'perperook?branch_name=sohrevardi',
#   'arghavan',
#   'mazzeh?branch_name=tavanir',
#   'tavanir',
#   'bowrani',
#   'hani?branch_name=andarzgoo',
#   'sadretehranrestaurant',
#   'Test',
#   'arshia?branch_name=%D9%81%D8%A7%D8%B7%D9%85%DB%8C',
#   'mobin',
#   'andarzgoo',
#   'tehran',
#   'kibo',
#   'burgerator?branch_name=tehran',
#   'sohrevardi',
#   'tehrani'],
#  'address': [': میدان فاطمی، خیابان گلها، خیابان مرداد، نبش خرداد، عرشیا سپهر دنیا (فاطمی)',
#   ': خیابان ظفر، خیابان گوی آبادی، خیابان راجیان، کوچه دلیری، پلاک 9، کترینگ غدیر',
#   ': سهروردی شمالی، خیابان آپادانا (خرمشهر)، نرسیده به قنبرزاده (مصلی)، پلاک 125، پیتزا پرپروک (آپادانا)',
#   ': آیت الله کاشانی، روبه روی شهرداری منطقه 5، پلاک 396، کترینگ ارغوان',
#   ': خیابان ولیعصر، خیابان توانیر، پلاک 10، رستوران مزه (توانیر)',
#   ': خیابان ولیعصر، خیابان توانیر، پلاک 10، رستوران مزه (توانیر)',
#   ': خیابان سهروردی جنوبی، خیابان اورامان، پلاک ۲۰، غذای خانگی بورانی',
#   ': بلوار اندرزگو، تقاطع بلوار کاوه، هانی (اندرزگو)',
#   ': یوسف آباد، بین کوچه 11 و 13، پلاک 77، رستوران صدر تهران',
#   ': خیابان ولیعصر، بلوار میرداماد، نرسیده به پل میرداماد، بازار بزرگ کیش، طبقه منفی 3، واحد 34، کترینگ بزرگ کیبو (سارا سابق)',
#   ': میدان فاطمی، خیابان گلها، خیابان مرداد، نبش خرداد، عرشیا سپهر دنیا (فاطمی)',
#   ': خیابان اسکندری جنوبی، پایین تر از آذربایجان، روبه روی فروشگاه اتکا، پلاک293، رستوران مبین',
#   ': بلوار اندرزگو، تقاطع بلوار کاوه، هانی (اندرزگو)',
#   ': جردن، بلوار صبا، پلاک 25، برگراتور',
#   ': خیابان ولیعصر، بلوار میرداماد، نرسیده به پل میرداماد، بازار بزرگ کیش، طبقه منفی 3، واحد 34، کترینگ بزرگ کیبو (سارا سابق)',
#   ': جردن، بلوار صبا، پلاک 25، برگراتور',
#   ': سهروردی شمالی، خیابان آپادانا (خرمشهر)، نرسیده به قنبرزاده (مصلی)، پلاک 125، پیتزا پرپروک (آپادانا)',
#   ': خیابان شهید بهشتی، خیابان احمد قصیر، کوچه ی مقدس، کترینگ طهرانی'],
#  'persian_name': ['عرشیا سپهر دنیا (فاطمی)',
#   'کترینگ غدیر',
#   'پیتزا پرپروک (آپادانا)',
#   'کترینگ ارغوان',
#   'رستوران مزه (توانیر)',
#   'رستوران مزه (توانیر)',
#   'غذای خانگی بورانی',
#   'رستوران هانی (اندرزگو)',
#   'رستوران صدر طهران (یوسف آباد)',
#   'کترینگ بزرگ کیبو (سارا سابق)',
#   'عرشیا سپهر دنیا (فاطمی)',
#   'رستوران مبین',
#   'رستوران هانی (اندرزگو)',
#   'برگراتور',
#   'کترینگ بزرگ کیبو (سارا سابق)',
#   'برگراتور',
#   'پیتزا پرپروک (آپادانا)',
#   'کترینگ طهرانی']}

# %%
df_restaurants=pd.DataFrame(restaurant)
df_restaurants
# Out:
#                                                  name  \
# 0                      %D9%81%D8%A7%D8%B7%D9%85%DB%8C
# 1                                      ghadircatering
# 2                    perperook?branch_name=sohrevardi
# 3                                            arghavan
# 4                          mazzeh?branch_name=tavanir
# 5                                             tavanir
# 6                                             bowrani
# 7                          hani?branch_name=andarzgoo
# 8                               sadretehranrestaurant
# 9                                                Test
# 10  arshia?branch_name=%D9%81%D8%A7%D8%B7%D9%85%DB%8C
# 11                                              mobin
# 12                                          andarzgoo
# 13                                             tehran
# 14                                               kibo
# 15                      burgerator?branch_name=tehran
# 16                                         sohrevardi
# 17                                            tehrani
#
#                                               address  \
# 0   : میدان فاطمی، خیابان گلها، خیابان مرداد، نبش ...
# 1   : خیابان ظفر، خیابان گوی آبادی، خیابان راجیان،...
# 2   : سهروردی شمالی، خیابان آپادانا (خرمشهر)، نرسی...
# 3   : آیت الله کاشانی، روبه روی شهرداری منطقه 5، پ...
# 4   : خیابان ولیعصر، خیابان توانیر، پلاک 10، رستور...
# 5   : خیابان ولیعصر، خیابان توانیر، پلاک 10، رستور...
# 6   : خیابان سهروردی جنوبی، خیابان اورامان، پلاک ۲...
# 7   : بلوار اندرزگو، تقاطع بلوار کاوه، هانی (اندرزگو)
# 8   : یوسف آباد، بین کوچه 11 و 13، پلاک 77، رستورا...
# 9   : خیابان ولیعصر، بلوار میرداماد، نرسیده به پل ...
# 10  : میدان فاطمی، خیابان گلها، خیابان مرداد، نبش ...
# 11  : خیابان اسکندری جنوبی، پایین تر از آذربایجان،...
# 12  : بلوار اندرزگو، تقاطع بلوار کاوه، هانی (اندرزگو)
# 13               : جردن، بلوار صبا، پلاک 25، برگراتور
# 14  : خیابان ولیعصر، بلوار میرداماد، نرسیده به پل ...
# 15               : جردن، بلوار صبا، پلاک 25، برگراتور
# 16  : سهروردی شمالی، خیابان آپادانا (خرمشهر)، نرسی...
# 17  : خیابان شهید بهشتی، خیابان احمد قصیر، کوچه ی ...
#
#                      persian_name
# 0         عرشیا سپهر دنیا (فاطمی)
# 1                     کترینگ غدیر
# 2          پیتزا پرپروک (آپادانا)
# 3                   کترینگ ارغوان
# 4            رستوران مزه (توانیر)
# 5            رستوران مزه (توانیر)
# 6               غذای خانگی بورانی
# 7          رستوران هانی (اندرزگو)
# 8   رستوران صدر طهران (یوسف آباد)
# 9    کترینگ بزرگ کیبو (سارا سابق)
# 10        عرشیا سپهر دنیا (فاطمی)
# 11                   رستوران مبین
# 12         رستوران هانی (اندرزگو)
# 13                       برگراتور
# 14   کترینگ بزرگ کیبو (سارا سابق)
# 15                       برگراتور
# 16         پیتزا پرپروک (آپادانا)
# 17                  کترینگ طهرانی

# %%
restaurant_name=[]
foods_name=[]
food_price=[]



def resturant_data_collector(link,**tags,**classes):
    req = requests.get(url)
    soup = BeautifulSoup(req.content, 'lxml')
    restaurant_name=restaurant_name.append(link[link.rfind('/'):])
    if tags.get() == 'span' and classes == 'my_product_title':
        
        food_name=food_name.append(soup.find(tag,calss=classes).get_text())
    if tag.get() == 'h4'and classes == 'kk-price':
        food_price=food_price.append(soup.find(tag,calss=classes).get_text()))
