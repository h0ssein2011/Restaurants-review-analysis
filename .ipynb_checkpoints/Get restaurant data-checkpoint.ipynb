# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from collections import OrderedDict
import time

# %%
# Set headers
headers = requests.utils.default_headers()
headers.update({ 'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'})



url = "https://snappfood.ir/restaurant/city/Tehran"
req = requests.get(url)
soup = BeautifulSoup(req.content, 'lxml')
# print(soup.prettify())

base_link='https://snappfood.ir'
links=[]
restaurant_links=[]

for sp in soup.find_all('div'):
    sp=sp.find('a')
    try:
        hrefs=sp.attrs['href']
       
        links.append(base_link+hrefs)
        
#         
        
#         
#              restaurant_links.append(base_link+hrefs)
            
        
    except:
        pass

links=set(links)
print(len(links))
print(links)
# Out:
# 26
# {'https://snappfood.ir/restaurant/menu/0wlr8p/burgerator/tehran', 'https://snappfood.ir/restaurant/menu/0jxzq3/sadretehranrestaurant', 'https://snappfood.ir/restaurant/menu/0y194g/tehrani', 'https://snappfood.ir/locale/en', 'https://snappfood.ir/restaurant/menu/0q6r92/kibo', 'https://snappfood.ir/restaurant/city/Tehran', 'https://snappfood.ir/restaurant/menu/0wlr8p/burgerator?branch_name=tehran', 'https://snappfood.irhttp://www.aparat.com/snappfood', 'https://snappfood.ir/restaurant/menu/3dqqkd/mazeh/tavanir', 'https://snappfood.ir/restaurant/menu/p61963/perperook?branch_name=sohrevardi', 'https://snappfood.ir/page/about', 'https://snappfood.ir/restaurant/menu/0rj2r1/ghadircatering', 'https://snappfood.ir/restaurant/menu/p61963/perperook/sohrevardi', 'https://snappfood.ir/restaurant/menu/37x8ym/arghavan', 'https://snappfood.ir/landing/zoodfoodexpress', 'https://snappfood.ir/restaurant/menu/po994q/bowrani', 'https://snappfood.ir/restaurant/menu/3dqqkd/mazzeh?branch_name=tavanir', 'https://snappfood.ir/restaurant/menu/0q6r92/Test', 'https://snappfood.ir/page/contact', 'https://snappfood.ir/restaurant/menu/3d5qew/hani/andarzgoo', 'https://snappfood.irjavascript:;', 'https://snappfood.ir/restaurant/menu/3d5qew/hani?branch_name=andarzgoo', 'https://snappfood.ir/restaurant/menu/32mzde/mobin', 'https://snappfood.ir/', 'https://snappfood.ir/landing/zfe', 'https://snappfood.ir/restaurant/menu/0jydnv/osve'}

# %%
real_restaurants=[]
for link in links:
    if 'menu' in link:
        real_restaurants.append(link)
    
real_restaurants
# Out:
# ['https://snappfood.ir/restaurant/menu/0wlr8p/burgerator/tehran',
#  'https://snappfood.ir/restaurant/menu/0jxzq3/sadretehranrestaurant',
#  'https://snappfood.ir/restaurant/menu/0y194g/tehrani',
#  'https://snappfood.ir/restaurant/menu/0q6r92/kibo',
#  'https://snappfood.ir/restaurant/menu/0wlr8p/burgerator?branch_name=tehran',
#  'https://snappfood.ir/restaurant/menu/3dqqkd/mazeh/tavanir',
#  'https://snappfood.ir/restaurant/menu/p61963/perperook?branch_name=sohrevardi',
#  'https://snappfood.ir/restaurant/menu/0rj2r1/ghadircatering',
#  'https://snappfood.ir/restaurant/menu/p61963/perperook/sohrevardi',
#  'https://snappfood.ir/restaurant/menu/37x8ym/arghavan',
#  'https://snappfood.ir/restaurant/menu/po994q/bowrani',
#  'https://snappfood.ir/restaurant/menu/3dqqkd/mazzeh?branch_name=tavanir',
#  'https://snappfood.ir/restaurant/menu/0q6r92/Test',
#  'https://snappfood.ir/restaurant/menu/3d5qew/hani/andarzgoo',
#  'https://snappfood.ir/restaurant/menu/3d5qew/hani?branch_name=andarzgoo',
#  'https://snappfood.ir/restaurant/menu/32mzde/mobin',
#  'https://snappfood.ir/restaurant/menu/0jydnv/osve']

# %%
#create a function to go trough each link and get desired data
# create a dict to store data
restaurant={}
restaurant['name']=[]
restaurant['address']=[]
restaurant['persian_name']=[]


#add name restaurants

    
for url in real_restaurants:
    tic=time.time()
    
    req = requests.get(url)
    soup = BeautifulSoup(req.content, 'lxml')
    En_name=url[url.rfind('/')+1:]
    address=soup.find('h2',itemprop="address",id="vendor-address").get_text().replace('آدرس','').strip()
    persian_name=soup.find('h1',itemprop="name",id="vendor-title").get_text().strip()
    
    
#     address=address[address.rfind('>'):]
    restaurant['name'].append(En_name)
    restaurant['address'].append(address)
    restaurant['persian_name'].append(persian_name)
    print((time.time()-tic),'second')
    

    
restaurant
# Out:
# 2.2421927452087402 second
# 2.1021530628204346 second
# 3.3988986015319824 second
# 2.996598482131958 second
# 2.737267255783081 second
# 2.5945992469787598 second
# 2.4671592712402344 second
# 2.2957658767700195 second
# 2.331822156906128 second
# 2.5155816078186035 second
# 2.157803535461426 second
# 2.2327499389648438 second
# 2.1477174758911133 second
# 2.277709484100342 second
# 2.226208209991455 second
# 2.4043962955474854 second
# 2.23587703704834 second
# {'name': ['tehran',
#   'sadretehranrestaurant',
#   'tehrani',
#   'kibo',
#   'burgerator?branch_name=tehran',
#   'tavanir',
#   'perperook?branch_name=sohrevardi',
#   'ghadircatering',
#   'sohrevardi',
#   'arghavan',
#   'bowrani',
#   'mazzeh?branch_name=tavanir',
#   'Test',
#   'andarzgoo',
#   'hani?branch_name=andarzgoo',
#   'mobin',
#   'osve'],
#  'address': [': جردن، بلوار صبا، پلاک 25، برگراتور',
#   ': یوسف آباد، بین کوچه 11 و 13، پلاک 77، رستوران صدر تهران',
#   ': خیابان شهید بهشتی، خیابان احمد قصیر، کوچه ی مقدس، کترینگ طهرانی',
#   ': خیابان ولیعصر، بلوار میرداماد، نرسیده به پل میرداماد، بازار بزرگ کیش، طبقه منفی 3، واحد 34، کترینگ بزرگ کیبو (سارا سابق)',
#   ': جردن، بلوار صبا، پلاک 25، برگراتور',
#   ': خیابان ولیعصر، خیابان توانیر، پلاک 10، رستوران مزه (توانیر)',
#   ': سهروردی شمالی، خیابان آپادانا (خرمشهر)، نرسیده به قنبرزاده (مصلی)، پلاک 125، پیتزا پرپروک (آپادانا)',
#   ': خیابان ظفر، خیابان گوی آبادی، خیابان راجیان، کوچه دلیری، پلاک 9، کترینگ غدیر',
#   ': سهروردی شمالی، خیابان آپادانا (خرمشهر)، نرسیده به قنبرزاده (مصلی)، پلاک 125، پیتزا پرپروک (آپادانا)',
#   ': آیت الله کاشانی، روبه روی شهرداری منطقه 5، پلاک 396، کترینگ ارغوان',
#   ': خیابان سهروردی جنوبی، خیابان اورامان، پلاک ۲۰، غذای خانگی بورانی',
#   ': خیابان ولیعصر، خیابان توانیر، پلاک 10، رستوران مزه (توانیر)',
#   ': خیابان ولیعصر، بلوار میرداماد، نرسیده به پل میرداماد، بازار بزرگ کیش، طبقه منفی 3، واحد 34، کترینگ بزرگ کیبو (سارا سابق)',
#   ': بلوار اندرزگو، تقاطع بلوار کاوه، هانی (اندرزگو)',
#   ': بلوار اندرزگو، تقاطع بلوار کاوه، هانی (اندرزگو)',
#   ': خیابان اسکندری جنوبی، پایین تر از آذربایجان، روبه روی فروشگاه اتکا، پلاک293، رستوران مبین',
#   ': ونک، گاندی شمالی، خیابان شریفی، پلاک 45، اسوه'],
#  'persian_name': ['برگراتور',
#   'رستوران صدر طهران (یوسف آباد)',
#   'کترینگ طهرانی',
#   'کترینگ بزرگ کیبو (سارا سابق)',
#   'برگراتور',
#   'رستوران مزه (توانیر)',
#   'پیتزا پرپروک (آپادانا)',
#   'کترینگ غدیر',
#   'پیتزا پرپروک (آپادانا)',
#   'کترینگ ارغوان',
#   'غذای خانگی بورانی',
#   'رستوران مزه (توانیر)',
#   'کترینگ بزرگ کیبو (سارا سابق)',
#   'رستوران هانی (اندرزگو)',
#   'رستوران هانی (اندرزگو)',
#   'رستوران مبین',
#   'اسوه']}

# %%
df_restaurants=pd.DataFrame(restaurant)
df_restaurants
# Out:
#                                 name  \
# 0                             tehran
# 1              sadretehranrestaurant
# 2                            tehrani
# 3                               kibo
# 4      burgerator?branch_name=tehran
# 5                            tavanir
# 6   perperook?branch_name=sohrevardi
# 7                     ghadircatering
# 8                         sohrevardi
# 9                           arghavan
# 10                           bowrani
# 11        mazzeh?branch_name=tavanir
# 12                              Test
# 13                         andarzgoo
# 14        hani?branch_name=andarzgoo
# 15                             mobin
# 16                              osve
#
#                                               address  \
# 0                           : جردن، بلوار صبا، پلا...
# 1                           : یوسف آباد، بین کوچه ...
# 2                           : خیابان شهید بهشتی، خ...
# 3                           : خیابان ولیعصر، بلوار...
# 4                           : جردن، بلوار صبا، پلا...
# 5                           : خیابان ولیعصر، خیابا...
# 6                           : سهروردی شمالی، خیابا...
# 7                           : خیابان ظفر، خیابان گ...
# 8                           : سهروردی شمالی، خیابا...
# 9                           : آیت الله کاشانی، روب...
# 10                          : خیابان سهروردی جنوبی...
# 11                          : خیابان ولیعصر، خیابا...
# 12                          : خیابان ولیعصر، بلوار...
# 13                          : بلوار اندرزگو، تقاطع...
# 14                          : بلوار اندرزگو، تقاطع...
# 15                          : خیابان اسکندری جنوبی...
# 16                          : ونک، گاندی شمالی، خی...
#
#                      persian_name
# 0                        برگراتور
# 1   رستوران صدر طهران (یوسف آباد)
# 2                   کترینگ طهرانی
# 3    کترینگ بزرگ کیبو (سارا سابق)
# 4                        برگراتور
# 5            رستوران مزه (توانیر)
# 6          پیتزا پرپروک (آپادانا)
# 7                     کترینگ غدیر
# 8          پیتزا پرپروک (آپادانا)
# 9                   کترینگ ارغوان
# 10              غذای خانگی بورانی
# 11           رستوران مزه (توانیر)
# 12   کترینگ بزرگ کیبو (سارا سابق)
# 13         رستوران هانی (اندرزگو)
# 14         رستوران هانی (اندرزگو)
# 15                   رستوران مبین
# 16                           اسوه

# %%
df_restaurants.iloc[3,1]
# Out:
# '                        : خیابان ولیعصر، بلوار میرداماد، نرسیده به پل میرداماد، بازار بزرگ کیش، طبقه منفی 3، واحد 34، کترینگ بزرگ کیبو (سارا سابق)'
